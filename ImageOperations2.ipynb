# %% [markdown]
# <a href="https://colab.research.google.com/github/VishalGhume/Python_AI/blob/master/ImageOperations2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import cv2 as cv
from matplotlib import pyplot as plt
img = cv2.imread("/content/sample_data/Images/Soldier.png")
mask = np.zeros(img.shape[:2],np.uint8)
bgdModel = np.zeros((1,65),np.float64)
fgdModel = np.zeros((1,65),np.float64)
rect = (50,50,450,290)
cv.grabCut(img,mask,rect,bgdModel,fgdModel,5,cv.GC_INIT_WITH_RECT)
mask2 = np.where((mask==2)|(mask==0),0,1).astype('uint8')
img = img*mask2[:,:,np.newaxis]
cv2_imshow(img)
#plt.imshow(img),plt.colorbar(),plt.show()
# Out:
# <PIL.Image.Image image mode=RGB size=321x481 at 0x7FA31734B710>

# %%
import cv2
from google.colab.patches import cv2_imshow
import numpy as np

#canvas = np.ones((1000,1000,3),dtype= 'uint8')*255
#cv2_imshow(canvas)

img = cv2.imread("/content/sample_data/Images/Flowers.jpeg")
resized_Img1 =cv2.resize(img, (0, 0), None, .25, .25)
#cv2_imshow(resized_Img)

Img2 = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
resized_Img2 =cv2.resize(Img2, (0, 0), None, .25, .25)

c = np.hstack((resized_Img1,resized_Img2))

cv2_imshow(c)
# Out:
# <PIL.Image.Image image mode=RGB size=2048x540 at 0x7FA31729A210>

# %%
import cv2
from google.colab.patches import cv2_imshow
import numpy as np

#canvas = np.ones((1000,1000,3),dtype= 'uint8')*255
#cv2_imshow(canvas)

img = cv2.imread("/content/sample_data/Images/Flowers.jpeg")
resized_Img1 =cv2.resize(img, (500, 500))
#cv2_imshow(resized_Img)

Img2 = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
resized_Img2 =cv2.resize(Img2, (500, 500))

c = np.hstack((resized_Img1,resized_Img2))

cv2_imshow(c)
# Out:
# <PIL.Image.Image image mode=RGB size=1000x500 at 0x7FA3171DFE50>

# %%
green = (0,255,0)
cv2.line(canvas,(0,0),(60,0),green,3)

blue = (255,0,0)
cv2.line(canvas,(0,0),(50,0),blue,3)

cv2_imshow(canvas)

rect = cv2.rectangle(canvas,(0,0),(200,200),red,3)
#cv2_imshow(rect)
