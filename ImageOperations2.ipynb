# %% [markdown]
# <a href="https://colab.research.google.com/github/VishalGhume/Python_AI/blob/master/ImageOperations2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
from google.colab.patches import cv2_imshow

image = cv2.imread("/content/sample_data/Images/Flowers.jpeg")
resized_Img =cv2.resize(image,(1000,400))
cv2_imshow(resized_Img)
# Out:
# <PIL.Image.Image image mode=RGB size=1000x400 at 0x7FA31D2DB790>
