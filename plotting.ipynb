# %% [markdown]
# <a href="https://colab.research.google.com/github/VishalGhume/Python_AI/blob/master/plotting.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import seaborn as sb
import pandas as pd
import matplotlib.pyplot as mpl

data = pd.read_excel("/content/temp.xlsx")
print(data)
ax = sb.scatterplot(x="Date",y="Process Name",hue="Status",data=data)
mpl.show()
# Out:
#          Date Process Name                 Status
# 0  2021-01-01      RPA-123  Requirement Gathering
# 1  2021-01-02      RPA-124      Key Stroke Review
# 2  2021-01-03      RPA-125         In Development
# 3  2021-01-04      RPA-126                    UAT
# 4  2021-01-05      RPA-127                    BAU
# 5  2021-01-06      RPA-128                    BAU
# 6  2021-01-07      RPA-129                    BAU
# 7  2021-01-08      RPA-130         In Development
# 8  2021-01-09      RPA-131  Requirement Gathering
# 9  2021-01-10      RPA-132                    UAT
# 10 2021-01-11      RPA-133                    UAT
