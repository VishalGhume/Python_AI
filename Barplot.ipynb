# %% [markdown]
# <a href="https://colab.research.google.com/github/VishalGhume/Python_AI/blob/master/Barplot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as mpl
import pandas as pd
import seaborn as sb

revenue_data = pd.read_excel("/content/RPA_Revenue.xlsx")
a = pd.DataFrame(revenue_data)
print(a)

sb.barplot(x="Revenue(In Billion)",y="Year",hue = "Tool",data = a)
mpl.show()
# Out:
#    Year                 Tool  Revenue(In Billion)
# 0  2015               UiPath                    6
# 1  2016           Blue Prism                    3
# 2  2017  Automation Anywhere                    4
# 3  2018       Power Automate                    2
# 4  2019               Tag UI                    1
# 5  2020                 Pega                    1

# %% [markdown]
# # New Section
