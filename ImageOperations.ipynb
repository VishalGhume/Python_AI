# %% [markdown]
# <a href="https://colab.research.google.com/github/VishalGhume/Python_AI/blob/master/ImageOperations.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install opencv-python

# %%
# !pip install opencv-python==3.4.2.17

# %%
import cv2
from google.colab.patches import cv2_imshow

# %%
#@title Default title text
#******************** Load Libraries *********************************************
import cv2
from google.colab.patches import cv2_imshow

#******************** Class And Functions ****************************************
class Image_Operations():
  def Read_Image(Img_Filepath):
      Original_image = cv2.imread(str(Img_Filepath))
      cv2_imshow(Original_image)
      print("\n")
      return Original_image

  def Add_Image_Text(Image,Text_to_Write,Width_Height,font,fontsacele,color,thikness):
     cv2.putText(Image,Text_to_Write,Width_Height,font,fontsacele,color,thikness)
     cv2_imshow(Image)
     print("\n")

  def Resize_Image(Image,Width_Hight):
      resize = cv2.resize(Original_image,(300,300))
      cv2_imshow(resize)
      print("\n")

  def Flip_Image(Image,Angle):
      if Angle == 90:
       New_Img = cv2.rotate(Image,cv2.cv2.ROTATE_90_CLOCKWISE)
       cv2_imshow(New_Img)
       print("\n")
      elif Angle == 180:
       New_Img = cv2.rotate(Image,cv2.cv2.ROTATE_180)
       cv2_imshow(New_Img)
       print("\n")
      elif Angle == 270:
        New_Img = cv2.rotate(Image,cv2.ROTATE_90_COUNTERCLOCKWISE)
        cv2_imshow(New_Img)
        print("\n")
      else:
          print("Please enter valid angle (90,180,270) :")


#***************************** Read Image ****************************************
Filepath = input("Please enter image filepath :")
Image = Image_Operations.Read_Image(Filepath)


#***************************** Add Text on Image *********************************

Text_to_Write = "Flower"
Width_Height = (2,50)
font = cv2.FONT_HERSHEY_PLAIN
color = (0,0,255)
thikness = 2
fontsacele = 1

Image_Operations.Add_Image_Text(Image,Text_to_Write,Width_Height,font,fontsacele,color,thikness)

#***************************** Resize Image **************************************

Updated_Width_Height = (400,400)
Image_Operations.Resize_Image(Filepath,Updated_Width_Height)

#***************************** Flip Image **************************************

Rotating_Angle = int(input("Enter rotating angle :"))
Image_Operations.Flip_Image(Image,Rotating_Angle)
# Out:
# Please enter image filepath :/content/sample_data/Images/Flower.jpg
# <PIL.Image.Image image mode=RGB size=183x275 at 0x7F0E5BEFCC90>
# <PIL.Image.Image image mode=RGB size=183x275 at 0x7F0E5BEFCC90>
# <PIL.Image.Image image mode=RGB size=300x300 at 0x7F0E5BEFCDD0>
# Enter rotating angle :270
# <PIL.Image.Image image mode=RGB size=275x183 at 0x7F0E5BEB3FD0>

# %%
import cv2
from google.colab.patches import cv2_imshow

Image = cv2.imread("/content/sample_data/Images/Flower.jpg")
New_Img = cv2.rotate(Image,cv2.cv2.ROTATE_180)
cv2_imshow(New_Img)
# Out:
# <PIL.Image.Image image mode=RGB size=183x275 at 0x7F0E5BF53A90>

# %% [markdown]
# # New Section

# %% [markdown]
# # New Section

# %%
Original_image = cv2.imread("/content/sample_data/Images/Flower.jpg")

Width_Hight = (2,50)
font = cv2.FONT_HERSHEY_PLAIN
color = (0,0,255)
thikness = 1
fontsacele = 1

flower.Add_Image_Text()

#******************** Read Image *************************************************


Image1 = Original_image



cv2.putText(Image1,"Flowers",Width_Hight,font,fontsacele,color,thikness)
cv2_imshow(Image1)

print("\n")

#******************** Image resize +and rotate Operations *************************
resize = cv2.resize(Original_image,(300,300))
cv2_imshow(resize)
print("\n")
